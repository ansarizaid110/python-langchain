# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("Hello, I am Zaid")
res.content
# Out:
# "Hello Zaid! It's nice to meet you. How's your day going? 😊 Is there anything you'd like to talk about or any help I can offer?"
