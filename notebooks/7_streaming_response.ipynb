# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq

llm = ChatOpenAI(model="gpt-4o", streaming=True)
llm_groq = ChatGroq(model="openai/gpt-oss-120b")

# %%
question = "What is GenAI?"

# %%
res = llm_groq.stream(question)
for chunk in res:
    print(chunk.content, end="")
# Out:
# **GenAI** (short for **generative artificial intelligence**) refers to a class of AI systems that can **create new content**—such as text, images, audio, video, code, or even 3‑D models—rather than just recognizing or classifying existing data.
#
# ---
#
# ## Core Idea
#
# - **Generative vs. Discriminative**
#   - *Discriminative* models (e.g., classic classifiers) learn to **distinguish** between categories (e.g., “spam” vs. “not spam”).
#   - *Generative* models learn the **underlying distribution** of the data and can **sample** from it, producing novel examples that look as if they came from the original dataset.
#
# ---
#
# ## How It Works (High‑Level)
#
# | Step | What Happens |
# |------|--------------|
# | **1. Training** | The model is fed massive amounts of data (text, images, code, etc.) and learns statistical patterns using deep neural networks (often transformers, diffusion models, or variational autoencoders). |
# | **2. Latent Representation** | The system compresses the input data into a high‑dimensional “latent space” where similar concepts are close together. |
# | **3. Sampling / Decoding** | When prompted, the model navigates this latent space and **generates** new data that follows the learned patterns. |
# | **4. Fine‑tuning / Conditioning** | Additional instructions, prompts, or control tokens steer the output toward a desired style, topic, or format. |
#
# ---
#
# ## Popular Families of GenAI Models
#
# | Modality | Representative Models | Typical Uses |
# |----------|-----------------------|--------------|
# | **Text** | GPT‑4, LLaMA 2, Claude, Gemini | Writing, summarization, translation, coding assistance, chatbots |
# | **Images** | DALL·E 3, Stable Diffusion, Midjourney, Imagen | Artwork, product mock‑ups, concept design, data augmentation |
# | **Audio** | AudioLM, MusicLM, Riffusion | Speech synthesis, music generation, sound‑effects creation |
# | **Video** | Phenaki, Make‑It‑Live, Runway Gen‑2 | Short clips, storyboarding, visual effects |
# | **Multimodal** | GPT‑4V, Gemini Vision, Flamingo | Combine text + images + video in a single interaction |
# | **Code** | Codex, Code Llama, StarCoder | Autocompletion, bug fixing, generating whole programs |
#
# ---
#
# ## Real‑World Applications
#
# | Domain | Example |
# |--------|---------|
# | **Content creation** | Blog posts, marketing copy, illustrations, music tracks |
# | **Design & prototyping** | Rapid UI mock‑ups, architectural concepts, 3‑D model drafts |
# | **Customer support** | Conversational agents that can answer complex queries |
# | **Software development** | Code suggestions, documentation generation, automated testing |
# | **Education & training** | Personalized tutoring, interactive simulations, language practice |
# | **Healthcare** | Synthetic medical images for training, summarizing patient notes |
# | **Scientific research** | Generating hypotheses, drafting papers, analyzing large datasets |
#
# ---
#
# ## Benefits
#
# 1. **Speed & Scale** – Produce high‑quality content in seconds that would take humans hours or days.
# 2. **Creativity Boost** – Suggest ideas outside the creator’s immediate imagination.
# 3. **Cost Reduction** – Lower labor costs for repetitive or draft‑level work.
# 4. **Accessibility** – Enable non‑experts to generate professional‑grade assets (e.g., a small business owner creating a logo without a designer).
#
# ---
#
# ## Challenges & Risks
#
# | Issue | Why It Matters |
# |-------|----------------|
# | **Hallucinations** | Models can generate plausible‑looking but factually wrong information. |
# | **Bias & Fairness** | Training data may contain societal biases that the model reproduces. |
# | **Intellectual‑Property** | Generated outputs can unintentionally copy copyrighted material. |
# | **Misuse** | Deepfakes, disinformation, spam, or automated phishing. |
# | **Resource Consumption** | Large models need massive compute and energy; sustainability is a concern. |
# | **Explainability** | Understanding *why* a model produced a specific output is still hard. |
#
# Mitigation strategies include fine‑tuning on curated data, using retrieval‑augmented generation, implementing human‑in‑the‑loop review, and applying robust policy & safety layers.
#
# ---
#
# ## Quick Analogy
#
# Think of a **recipe book**:
#
# - A **discriminative** AI is like a food critic who can tell you whether a dish is “spicy” or “sweet.”
# - A **generative** AI is like a chef who, after studying thousands of recipes, can **invent a brand‑new dish** that still tastes good.
#
# ---
#
# ## TL;DR
#
# *GenAI* = AI that **creates** new content (text, images, audio, code, etc.) by learning the patterns of existing data and then **sampling** from that learned knowledge. It powers chatbots, image generators, code assistants, and many other tools that are reshaping how we produce and interact with digital media—while also raising important ethical and technical challenges.
