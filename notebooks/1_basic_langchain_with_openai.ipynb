# %%
from dotenv import load_dotenv
load_dotenv()

# %%
import os

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5-mini-2025-08-07")
res = llm.invoke("Who is president of India?")
res.content

# %% [markdown]
# ### Connect with google gemini modle

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
res = llm.invoke("What is GenAI? Explain me in short.")
print(res.content)

# %% [markdown]
# ### Connect with apenai modle

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
res = llm.invoke("What is GenAI? Explain me in short.")
print(res.content)

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model_name="claude-opus-4-7")
res = llm.invoke("What is GenAI? Explain me in short.")
print(res.content)

# %% [markdown]
# ### Static Prompts

# %%
prompts = [
    ("system", "You are a python developer."),
    ("user", "How to sort an array.")
]

res = llm.invoke(prompts)
print(res.content)

# %% [markdown]
# ### Hugging Face

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
prompts = [
    ("system", "You are a java developer."),
    ("user", "How to sort an array.")
]

res = llm.invoke(prompts)
print(res.content)
